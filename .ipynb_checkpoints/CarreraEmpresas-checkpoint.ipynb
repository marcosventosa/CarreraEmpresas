# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from pretty_html_table import build_table
import base64

# %%
fsize = 13
tsize = 18
tdir = 'in'
major = 5.0
minor = 3.0
lwidth = 0.8
lhandle = 2.0
plt.style.use('default')
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family']='serif'
plt.rcParams['font.size'] = fsize
plt.rcParams['legend.fontsize'] = tsize
plt.rcParams['xtick.direction'] = tdir
plt.rcParams['ytick.direction'] = tdir
plt.rcParams['xtick.major.size'] = major
plt.rcParams['xtick.minor.size'] = minor
plt.rcParams['ytick.major.size'] = 5.0
plt.rcParams['ytick.minor.size'] = 3.0
plt.rcParams['axes.linewidth'] = lwidth
plt.rcParams['legend.handlelength'] = lhandle
plt.rcParams["figure.figsize"] = (7,4)

# %%
params = [['F','10k'],['M','10k'],['F','6k'],['M','6k']]

# %%
r = requests.get('https://www.carreradelasempresas.com/clasificaciones23/buscador_absoluta.php?sex=M&car=6K')
parsed_html = BeautifulSoup(r.content)
c = parsed_html.body.find('div', attrs={'class':'buscar'})

# %%
df = pd.DataFrame(columns =["Distancia", "Genero", "Posicion", "Nombre", "Empresa", "Tiempo"] )
for g, k in params:
    r = requests.get('https://www.carreradelasempresas.com/clasificaciones23/buscador_absoluta.php?sex={}&car={}'.format(g,k))
    parsed_html = BeautifulSoup(r.content)
    c = parsed_html.body.find('div', attrs={'class':'buscar'})
    for elm in c.find_all('p'):
        pattern = r'<p><span class="rojo">(\d+)<\/span>  (.*) - <strong>(.*)<\/strong> - ([\d:]+)<\/p>'
        match = re.search(pattern, str(elm))
        df = pd.concat([df,pd.DataFrame(data = [[k]+[g]+list(match.groups())], columns =["Distancia", "Genero", "Posicion", "Nombre", "Empresa","Tiempo"] )])

# %%
df["Empresa"] = df["Empresa"].str.replace("&amp;","&")
df["Empresa"] = df["Empresa"].replace("","Sin Empresa")
df["Nombre"] = df["Nombre"].str.replace("\t"," ")

# %%
df
# Out:
#    Distancia Genero Posicion                         Nombre  \
# 0        10k      F        1               RUTH LEON CASADO
# 0        10k      F        2       AINEGUE DEL OLMO JIMENEZ
# 0        10k      F        3             LEIRE VIDAL ALVARO
# 0        10k      F        4                MARINA TABERNER
# 0        10k      F        5  MARIA FATIMA DE FREITAS PINTO
# ..       ...    ...      ...                            ...
# 0         6k      M     4205              JESÚS RAMOS MUÑOZ
# 0         6k      M     4206         ADRIÁN DURÁN RONQUILLO
# 0         6k      M     4207                BENOIT SAMPERIZ
# 0         6k      M     4208                   JOSE PERALES
# 0         6k      M     4209  Johan Miguel Rodriguez Zapata
#
#                           Empresa          Tiempo  Ritmo (min/km)  min/km
# 0                CHEMA CARPINTERO 0 days 00:37:19           3.732   3.732
# 0           MECO PADEL TEAM, S.L. 0 days 00:38:09           3.815   3.815
# ...

# %%
#df["Tiempo"] = pd.to_datetime(df["Tiempo"],format ="%H:%M:%S")

# %%
df["Tiempo"] = pd.to_timedelta(df["Tiempo"])
df["min/km"] = (df['Tiempo'].astype('timedelta64[s]') / 60 / df["Distancia"].str[:-1].astype(int)).round(3)

# %%
df
# Out:
#    Distancia Genero Posicion                         Nombre  \
# 0        10k      F        1               RUTH LEON CASADO
# 0        10k      F        2       AINEGUE DEL OLMO JIMENEZ
# 0        10k      F        3             LEIRE VIDAL ALVARO
# 0        10k      F        4                MARINA TABERNER
# 0        10k      F        5  MARIA FATIMA DE FREITAS PINTO
# ..       ...    ...      ...                            ...
# 0         6k      M     4205              JESÚS RAMOS MUÑOZ
# 0         6k      M     4206         ADRIÁN DURÁN RONQUILLO
# 0         6k      M     4207                BENOIT SAMPERIZ
# 0         6k      M     4208                   JOSE PERALES
# 0         6k      M     4209  Johan Miguel Rodriguez Zapata
#
#                           Empresa          Tiempo  Ritmo (min/km)  min/km
# 0                CHEMA CARPINTERO 0 days 00:37:19           3.732   3.732
# 0           MECO PADEL TEAM, S.L. 0 days 00:38:09           3.815   3.815
# ...

# %%
F10k = len(df[(df["Distancia"] == '10k') & (df["Genero"] == "F")])
M10k = len(df[(df["Distancia"] == '10k') & (df["Genero"] == "M")])
F6k = len(df[(df["Distancia"] == '6k') & (df["Genero"] == "F")])
M6k = len(df[(df["Distancia"] == '6k') & (df["Genero"] == "M")])
print(F10k,M10k,F10k,F6k)
print(F10k/(F10k+M10k))
print(F6k/(F6k+M6k))
# Out:
# 1573 5919 1573 4884
# 0.2099572877736252
# 0.5371164632134608

# %%
df[df["Empresa"] == 'SILLERAS ASESORES JURIDICOS SL']
#df[df["Empresa"] == 'AQUILA GROUP']
# Out:
#   Distancia Genero Posicion                          Nombre  \
# 0        6k      F     1725           YOLANDA SANCHEZ NIEVA
# 0        6k      F     2965       CRISTINA DIEGUEZ CARRASCO
# 0        6k      F     3161         SEILA PIÑEIRO RODRIGUEZ
# 0        6k      F     4246          JESSICA MINGUEZ SIERRA
# 0        6k      F     4364           ANA MORALES FERNANDEZ
# 0        6k      F     4367    MAYRA FERREIRA ESTIGARRRIBIA
# 0        6k      F     4701         ESTHER MANCHEÑO ROZALEN
# 0        6k      F     4702         HERMINIA MONZON RAMIREZ
# 0        6k      F     4703         MARIA NOTARIO ALCANTARA
# 0        6k      F     4704                INES ARMADA SAEZ
# 0        6k      F     4705    MARIA DEL MAR VALLS PALOMINO
# 0        6k      F     4706         MARIA MARTINEZ MARTINEZ
# 0        6k      F     4707  MARIA TERESA SILLERAS MARTINEZ
# 0        6k      M      748         VICTOR MUÑOZ VILLANUEVA
# 0        6k      M      749         CESAR SILLERAS MARTINEZ
# ...

# %%
for g, k in params:
    dfF = df[(df["Distancia"]==k) & (df["Genero"] == g)]
    for emp in set(df["Empresa"]):
        file_name_string = re.sub(r'[\\/*?:"<>|]',"",emp)
        with open('Empresas/Ranking_{}_{}.html'.format(g+k,file_name_string), 'w', encoding="utf-8") as f:
            table = dfF[dfF["Empresa"] == emp][["Nombre","Tiempo","min/km"]]
            table = table.reset_index(drop=True).reset_index().rename(columns={"index":'Pos.'})
            table["Tiempo"] = table["Tiempo"].astype(str).map(lambda x: x[7:])
            table["Pos."]+= 1
            
            color = 'blue_light' if g == 'M' else 'red_light'
            #f.write(build_table(table, 'blue_light',font_size='14px'))
            f.write(build_table(table,color = color, font_size='14px'))

# %%
with open('test.html', 'w') as f:
    f.write(table.to_html(index=False))

# %%
table
# Out:
#     Pos.                           Empresa  Personas     Media
# 0      1                              RTVE        20  00:30:35
# 1      2                PLUS ULTRA SEGUROS        10  00:32:52
# 2      3     FHECOR INGENIEROS CONSULTORES        18  00:34:13
# 3      4    ING BANK NV SUCURSAL EN ESPAÑA        10  00:34:32
# 4      5                            MAPFRE        15  00:35:00
# ..   ...                               ...       ...       ...
# 89    90                    FUNESPAÑA 2 SL        16  00:52:11
# 90    91                           ELECNOR        15  00:52:52
# 91    92            ACIERTA ASISTENCIA S.A        11  00:53:14
# 92    93  MONDELEZ ESPAÑA SERVICES, S.L.U.        17  00:55:01
# 93    94            EXIDE TECHNOLOGIES SLU        23  00:55:32
#
# [94 rows x 4 columns]

# %%
for g, k in params:
    dfG = df[(df["Genero"] == g) & (df["Distancia"] == k)].groupby(['Empresa'])['Tiempo'].agg(['sum','size'])
    dfG = dfG.rename(columns={'size': 'Personas'})
    dfG["Media"] = dfG['sum'].div(dfG['Personas'])
    dfG = dfG.drop(columns = ["sum"]).reset_index()
    dfG["min/km"] = (dfG['Media'].astype('timedelta64[s]') / 60 / int(k[:-1])).round(3)
    dfG["Media"] = dfG["Media"].astype(str).map(lambda x: x[7:15])
    with open('Rankings/Ranking{}.html'.format(g+k), 'w') as f:
        table = dfG[dfG["Personas"]>=10].sort_values(by = "Media").reset_index(drop = True).reset_index().rename(columns={"index":'Pos.'})
        table["Pos."]+= 1
        color = 'blue_light' if g == 'M' else 'red_light'
        f.write(build_table(table, color,font_size='13px'))

# %%
dfG = pd.DataFrame(data = set(df["Empresa"]), columns = ["Empresa"])
dfG = dfG.sort_values(by = "Empresa").reset_index(drop= True)
#dfG['Empresa'] = dfG['Empresa'].apply(lambda x: '<a href="Empresas/Ranking_{0}.html">{1}</a>'.format(re.sub(r'[\\/*?:"<>|]',"",x), x))
personas = []
lF10k = []
lM10k = []
lF6k = []
lM6k = []
for index, row in dfG.iterrows():
    personas += [df[(df["Empresa"]== row["Empresa"])]["Tiempo"].count()]
    lF10k += [str(df[(df["Empresa"]== row["Empresa"]) & (df["Genero"] == "F") & (df["Distancia"] == "10k")]["Tiempo"].mean())[7:15]]
    lM10k += [str(df[(df["Empresa"]== row["Empresa"]) & (df["Genero"] == "M") & (df["Distancia"] == "10k")]["Tiempo"].mean())[7:15]]
    lF6k += [str(df[(df["Empresa"]== row["Empresa"]) & (df["Genero"] == "F") & (df["Distancia"] == "6k")]["Tiempo"].mean())[7:15]]
    lM6k += [str(df[(df["Empresa"]== row["Empresa"]) & (df["Genero"] == "M") & (df["Distancia"] == "6k")]["Tiempo"].mean())[7:15]]

dfG["Personas"] = personas
dfG["Media 10K Fem."] = lF10k
dfG["Media 10K Masc."] = lM10k
dfG["Media 6K Fem."] = lF6k
dfG["Media 6K Masc."] = lM6k
    
htmlTable = '''
<p><table border="0" class="dataframe">
  <thead>
    <tr style="text-align: right;">
      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Empresa</th>
      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Personas</th>
      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #823535;text-align: left;border-bottom: 2px solid #823535;padding: 0px 20px 0px 0px;width: auto">Media 10k Fem.</th>
      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Media 10k Masc.</th>
      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #823535;text-align: left;border-bottom: 2px solid #823535;padding: 0px 20px 0px 0px;width: auto">Media 6k Fem.</th>
      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Media 6k Masc.</th>
    
    </tr>
  </thead>
  <tbody>
'''
for index, row in dfG.iterrows():
    
    color = '#D9E1F2' if index % 2 else "white"
    htmlTable+= '''
    <tr>
    <td style = "background-color: {0};font-family: Century Gothic, sans-serif;font-size: 13px;text-align: left;padding: 0px 20px 0px 0px;width: auto"><a href="{1}"</a>{2}</td>
    <td style = "background-color: {0};font-family: Century Gothic, sans-serif;font-size: 13px;text-align: center;padding: 0px 20px 0px 0px;width: auto">{3}</td>
    <td style = "background-color: {0};font-family: Century Gothic, sans-serif;font-size: 13px;text-align: center;padding: 0px 20px 0px 0px;width: auto">{4}</td>
    <td style = "background-color: {0};font-family: Century Gothic, sans-serif;font-size: 13px;text-align: center;padding: 0px 20px 0px 0px;width: auto">{5}</td>
    <td style = "background-color: {0};font-family: Century Gothic, sans-serif;font-size: 13px;text-align: center;padding: 0px 20px 0px 0px;width: auto">{6}</td>
    <td style = "background-color: {0};font-family: Century Gothic, sans-serif;font-size: 13px;text-align: center;padding: 0px 20px 0px 0px;width: auto">{7}</td>
    </tr>
    '''.format(color, "Empresas/Ranking_{0}.html".format(re.sub(r'[\\/*?:"<>|]',"",row["Empresa"])), row["Empresa"], row["Personas"], row["Media 10K Fem."], row["Media 10K Masc."], row["Media 6K Fem."], row["Media 6K Masc."])
htmlTable += '''
</tbody>
</table></p>
'''
with open('Empresas.html', 'w') as f:
    #f.write(build_table(dfG, color = "blue_light",font_size='13px'))
    #f.write(dfG.to_html(escape=False))
    f.write(formato_base.format("Carrera de las empresas 2023", htmlTable))

# %%
[str(df[(df["Empresa"]== "ACCIONA") & (df["Genero"] == "M") & (df["Distancia"] == "6k")]["Tiempo"].mean())[7:15]]
# Out:
# ['00:43:40']

# %%
df[(df["Empresa"]== "IBERDROLA") & (df["Genero"] == "F") & (df["Distancia"] == "10k")]["Tiempo"].mean()
# Out:
# Timedelta('0 days 00:57:43.588235294')

# %%
4%2
# Out:
# 0

# %%
set([k for _, k in params])
# Out:
# {'10k', '6k'}

# %%
for k in set([k for _, k in params]):
    dfF = df[df["Distancia"]==k]
    datosM = (dfF[dfF["Genero"]=="M" ]['Tiempo'].astype('timedelta64[s]') / 60)
    datosF = (dfF[dfF["Genero"]=="F" ]['Tiempo'].astype('timedelta64[s]') / 60)
    print(k)
    datosM.plot(kind = "hist",bins = 30,density=True,color = 'blue',edgecolor = 'black',alpha=0.5,label='_nolegend_')
    datosF.plot(kind = "hist",bins = 30,density=True,color = 'pink',edgecolor = 'black',alpha=0.5,label='_nolegend_')
    plt.axvline(datosM.mean(), color='blue', linestyle='-', linewidth=1.5,label='Media hombres')
    plt.axvline(datosF.mean(), color='#cf3476', linestyle='-', linewidth=1.5,label='Media mujeres')
    plt.xlabel('Minutos')
    plt.ylabel('Densidad de probabilidad')
    plt.title("Carrera de las empresas {}".format(k))
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().legend(loc="upper right",fontsize=10)
    plt.yticks([])
    plt.savefig("Distribuciones/Distribucion_{}.png".format(k),format="png",dpi=1500)
    plt.show()
# Out:
# 10k
# 6k

# %%
for k in set([k for _, k in params]):
    dfF = df[df["Distancia"]==k]
    datosM = (dfF[dfF["Genero"]=="M" ]['Tiempo'].astype('timedelta64[s]') / 60)
    datosF = (dfF[dfF["Genero"]=="F" ]['Tiempo'].astype('timedelta64[s]') / 60)
    for emp in set(df["Empresa"]):
        file_name_string = re.sub(r'[\\/*?:"<>|]',"",emp)
        print(k, emp)
        dfEmp = dfF[dfF["Empresa"]==emp]
        datosMEmp = (dfEmp[dfEmp["Genero"]=="M" ]['Tiempo'].astype('timedelta64[s]') / 60)
        datosFEmp = (dfEmp[dfEmp["Genero"]=="F" ]['Tiempo'].astype('timedelta64[s]') / 60)
        datosM.plot(kind = "hist",bins = 30,density=True,color = 'blue',edgecolor = 'black',alpha=0.5,label='_nolegend_')
        datosF.plot(kind = "hist",bins = 30,density=True,color = 'pink',edgecolor = 'black',alpha=0.5,label='_nolegend_')
        
        plt.axvline(datosM.mean(), color='blue', linestyle='-', linewidth=1.5,label='Media hombres')
        plt.axvline(datosF.mean(), color='#cf3476', linestyle='-', linewidth=1.5,label='Media mujeres')
        if(len(datosMEmp)>0):
            plt.axvline(datosMEmp.mean(), color='blue', linestyle='-.', linewidth=1.5,label='Media hombres empresa')
        if(len(datosFEmp)>0):
            plt.axvline(datosFEmp.mean(), color='#cf3476', linestyle='-.', linewidth=1.5,label='Media mujeres empresa')
        plt.xlabel('Minutos')
        plt.ylabel('Densidad de probabilidad')
        plt.title("Carrera de las empresas {}".format(k))
        plt.gca().spines['right'].set_visible(False)
        plt.gca().spines['top'].set_visible(False)
        plt.gca().legend(loc="upper right",fontsize=10)
        plt.yticks([])
        if(len(datosFEmp)>0 or len(datosMEmp)>0):
            plt.savefig("Distribuciones/Distribucion_{}_{}.jpg".format(k, file_name_string))
        plt.show()
# Out:
# 10k BETWEEN TECHNOLOGY
# 10k INES INGENIEROS CONSULTORES
# 10k BAUMIT SL
# 10k TRESSIS SOCIEDAD DE VALORES S.A.
# 10k GMP PROPERTY SOCIMI
# 10k EUROSMC, S.A.
# 10k QUADRANT TRAVEL TECHNOLOGY SL
# 10k CHEP
# 10k BELEVELS
# 10k SILLERAS ASESORES JURIDICOS SL
# 10k THETARAY
# 10k AUSOLAN
# 10k GRUPO GESTIONA-T GESTORES
# 10k GFT IT CONSULTING SLU
# 10k ID LOGISTICS
# 10k INTEGRA ITO SL
# 10k SEAPLACE
# 10k MOBILIZE FINANCIAL SERVICES
# 10k STELLANTIS FINANCIAL SERVICES ESPAÑA
# 10k ATL 12 CAPITAL INVERSIONES A.V., S.A.,
# 10k IKOS SPANISH HOTELS MANAGEMENT S.L.
# 10k CORREOS TELECOM, S.A SME
# 10k BIOMERIEUX ESPAÑA
# 10k HIPOGES IBERIA, SL
# 10k GRUPO TAT - ASESORIA DE EMPRESAS
# 10k INFORMACION CONTROL Y PLANIFICACION SA
# 10k CLEVERGY
# 10k BOEING AEROSPACE SPAIN SL
# 10k GOATEX GROUP S.L.
# 10k CGI INFORMATION SYSTEMS AND MANAGEMENT CONSULTANTS ESPAÑA S.A.
# 10k ASSERLEX GRADUADOS SOCIALES S.L
# 10k J.V
# 10k ALISEDA SERVICIOS DE GESTION INMOBILIARIA, S.L
# ...

# %%
dfG
# Out:
#                                  Empresa  Personas     Media  min/km
# 0                                                7  00:47:16   7.878
# 1              ABANCA GESTION DE ACTIVOS         4  00:34:50   5.806
# 2      ABEI ENERGY AND INFRASTRUCTURE SL         4  00:41:57   6.992
# 3    ABG INTELLECTUAL PROPERTY LAW, S.L.         3  00:35:55   5.986
# 4           ACADEMIA DE ESTUDIOS MIR SLU         1  01:01:58  10.328
# ..                                   ...       ...       ...     ...
# 696                   YABA VENTURES, SAU         1  00:40:49   6.803
# 697   ZABALA INNOVATION CONSULTING, S.A.         2  00:40:20   6.722
# 698                     ZEUS CONTROL, SA        10  00:42:15   7.042
# 699             ZOOPLUS SERVICES ESP S.L         2  00:45:02   7.506
# 700                        ZURICH ESPAÑA         1  00:35:54   5.983
#
# [701 rows x 4 columns]

# %%
datosM = (df['Tiempo'].astype('timedelta64[s]') / 60)

# %%
datosF = (df['Tiempo'].astype('timedelta64[s]') / 60)

# %%
datosM.plot(kind = "hist",bins = 40,density=True,color = 'blue',edgecolor = 'black',alpha=0.5,label='_nolegend_')
datosF.plot(kind = "hist",bins = 30,density=True,color = 'pink',edgecolor = 'black',alpha=0.5,label='_nolegend_')

# %%
dfG = df.groupby(['Empresa'])['Tiempo'].agg(['sum','size'])
dfG["avg"] = dfG['sum'].div(dfG['size'])
dfG = dfG.drop(columns = ["sum"]).reset_index()
dfG
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b314199491d2> in <module>
# ----> 1 dfG = df.groupby(['Empresa'])['Tiempo'].agg(['sum','size'])
#       2 dfG["avg"] = dfG['sum'].div(dfG['size'])
#       3 dfG = dfG.drop(columns = ["sum"]).reset_index()
#       4 dfG
#
# NameError: name 'df' is not defined

# %%
df.groupby("Empresa")\
       .agg({'Nombre':'size', 'Tiempo':'mean'}) \
       .rename(columns={'Nombre':'count','Tiempo':'mean_sent'}) \
       .reset_index()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-142-972d85ddfaaf> in <module>
#       1 df.groupby("Empresa")\
# ----> 2        .agg({'Nombre':'size', 'Tiempo':'mean'}) \
#       3        .rename(columns={'Nombre':'count','Tiempo':'mean_sent'}) \
#       4        .reset_index()
#
# ~\miniconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# --> 945         result, how = aggregate(self, func, *args, **kwargs)
#     946         if how is None:
#     947             return result
#
# ~\miniconda3\lib\site-packages\pandas\core\aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     580     elif is_dict_like(arg):
#     581         arg = cast(AggFuncTypeDict, arg)
# --> 582         return agg_dict_like(obj, arg, _axis), True
# ...

# %%
for key, val in df.groupby("Empresa")["Nombre"].count().sort_values(ascending = False).iteritems():
    print(key, val, val/df.count()[0]*100, "%")
# Out:
# DELOITTE, S.L. 142 3.3721206364284018 %
# ILUNION 99 2.3509855141296603 %
# GMV 97 2.303490857278556 %
# REPSOL COMERCIAL DE P.P., S.A. 73 1.7335549750653052 %
# CARREFOUR LIFE 69 1.6385656613630968 %
# PWC 58 1.3773450486820233 %
# EY ESPAÑA 54 1.2823557349798147 %
# CANAL DE ISABEL II 52 1.2348610781287106 %
# BANKINTER SA 47 1.11612443600095 %
# AHORRAMAS, S.A. 45 1.0686297791498456 %
# TECNICAS REUNIDAS 44 1.0448824507242935 %
# AUTONOMOS 40 0.9498931370220851 %
# GRUPO MUTUA MADRILEÑA 38 0.9023984801709808 %
# AMAZON ESPAÑA 29 0.6886725243410117 %
# INDRA SOLUCIONES TI S.L.U 27 0.6411778674899073 %
# ADIF 27 0.6411778674899073 %
# ACCENTURE 27 0.6411778674899073 %
# GMS MANAGEMENT SOLUTIONS SL 26 0.6174305390643553 %
# AL AIR LIQUIDE ESPAÑA SA 24 0.5699358822132511 %
# EXIDE TECHNOLOGIES SLU 23 0.5461885537876989 %
# GSK 23 0.5461885537876989 %
# TECNICA Y PROYECTOS S.A 21 0.49869389693659466 %
# FUNDACION CORAZON DE TITAN 21 0.49869389693659466 %
# ...

# %%
df.count()[0]
# Out:
# 4211

# %%
string = '<p><span class="rojo">2</span>  GUILLERMO PÁRAMO IGLESIAS - <strong>IMTO PACK & S.L.</strong> - 00:21:49</p>'
pattern = r'<p><span class="rojo">(\d+)<\/span>  (.*) - <strong>(.*)<\/strong> - ([\d:]+)<\/p>'
match = re.search(pattern, string)

# %%
list(match.groups())
# Out:
# ['2', 'GUILLERMO PÁRAMO IGLESIAS', 'IMTO PACK & S.L.', '00:21:49']

# %%
str(c.find_all('p')[0])
# Out:
# '<p><span class="rojo">1</span>  CRISTIAN MARTINEZ ALAEZ - <strong>DECATHLON</strong> - 00:20:55</p>'

# %%
formato_base = '''<html>
<head>
<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
  <script src="https://code.jquery.com/jquery-3.2.1.slim.min.js" integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN" crossorigin="anonymous"></script>
  <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js" integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q" crossorigin="anonymous"></script>
  <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js" integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl" crossorigin="anonymous"></script>
  <link rel="stylesheet" href="font-awesome-4.7.0/css/font-awesome.min.css">
  <link rel="stylesheet" type="text/css" href="style.css">

</head>


<body>
  <div class="row align-text-center">
    <div class="col-6 mx-auto">
      <h1 class="title display-4" style="color: #212529; text-align:center;">{0}</h1>
    </div>
  </div>
  <hr style="border-top: 2px solid ; padding-bottom:0px ;padding-top:15px;">

<div class = "row justify-content-md-center" style=" margin: 0 auto ;margin-left:50px;margin-right:50px;">
    {1}
</div>
  
  
  
<div class = "row justify-content-md-center" style=" margin: 0 auto ;margin-left:50px;margin-right:50px;">

{2}

</div>

</body>
</html>
'''
formato_distribuciones = '''   

    <div aling = 'col center'>
      <img src="../Distribuciones/Distribucion_{0}_{1}.jpg"  width="900" >
    </div>

'''

formato_base_ranking = '''<html>
<head>
<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
  <script src="https://code.jquery.com/jquery-3.2.1.slim.min.js" integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN" crossorigin="anonymous"></script>
  <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js" integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q" crossorigin="anonymous"></script>
  <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js" integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl" crossorigin="anonymous"></script>
  <link rel="stylesheet" href="font-awesome-4.7.0/css/font-awesome.min.css">
  <link rel="stylesheet" type="text/css" href="style.css">

</head>


<body>
  <div class="row align-text-center">
    <div class="col-6 mx-auto">
      <h1 class="title display-4" style="color: #212529; text-align:center;">{}</h1>
    </div>
  </div>
  <hr style="border-top: 2px solid ; padding-bottom:0px ;padding-top:15px;">
  
  <div class = "row justify-content-md-center" style=" margin: 0 auto ;margin-left:50px;margin-right:50px;">
    <div aling = 'col center'>
      <img src="../Distribuciones/Distribucion_10k.png"  width="900" >
    </div>
    <div aling = 'col center'>
      <img src="../Distribuciones/Distribucion_6k.png"  width="900" >
    </div>
  </div>


<div class = "row justify-content-md-center" style=" margin: 0 auto ;margin-left:50px;margin-right:50px;">

{}

</div>

</body>
</html>
'''

formato_tabla = '''<div aling = 'col center'> 
<h2 class="title display-5" style="color: #212529; text-align:center;">{}</h2>
{} 


</div>'''

# %%
for emp in set(df["Empresa"]):
    file_name_string = your_string = re.sub(r'[\\/*?:"<>|]',"",emp)
    
    html_distribuciones = ''
    for k in set([k for _, k in params]):
        if len(df[(df["Distancia"]==k) & (df["Empresa"] ==emp)])>0:
            html_distribuciones += formato_distribuciones.format(k,file_name_string)
    
    html_tablas = ''
    for g, k in params:
        dfF = df[(df["Distancia"]==k) & (df["Genero"] == g) & (df["Empresa"] ==emp)]
        if len(dfF)>0:
            with open('Empresas/Ranking_{}_{}.html'.format(g+k,file_name_string), 'r', encoding="utf-8") as f:
                t = f.read()
                gen = "Masc." if g == 'M' else "Fem."
                html_tablas += formato_tabla.format(gen+' '+ k,t)
    
    
    
    with open('Empresas/Ranking_{}.html'.format(file_name_string), 'w', encoding="utf-8") as f:
        f.write(formato_base.format(emp,html_distribuciones, html_tablas))

# %%
html_tablas = ''
for g, k in params:
    with open('Rankings/Ranking{}.html'.format(g+k), 'r') as f:
        t = f.read()
        gen = "Masc." if g == 'M' else "Fem."
        html_tablas += formato_tabla.format(gen+' '+ k,t)
        
with open('Rankings/Ranking.html', 'w', encoding="utf-8") as f:
    f.write(formato_base_ranking.format("Ranking Empresas", html_tablas))

# %%
html_tablas
# Out:
# '<div aling = \'col center\'> \n<h2 class="title display-5" style="color: #212529; text-align:center;">Fem. 10k</h2>\n<p><table border="0" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Pos.</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Empresa</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Personas</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: 15px;color: #305496;text-align: left;bor
# ...
